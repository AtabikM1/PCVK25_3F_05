# %% [markdown]
# <a href="https://colab.research.google.com/github/AtabikM1/PCVK25_3F_05/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

#accessing My Google Drive
drive.mount('/content/gdrive')
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np


img_path = '/content/gdrive/MyDrive/PCVK_MM/Images/kitten01.jpg'
plt.imshow(img)

img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

img_gray = cv.imread(img_path, cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap="gray")
plt.imshow(img_gray, cmap='magma')

img4 = cv.resize(img3,(512,1024))
plt.imshow(img4)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
