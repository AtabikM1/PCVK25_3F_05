# %% [markdown]
# <a href="https://colab.research.google.com/github/AtabikM1/PCVK25_3F_05/blob/main/kelompok.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#tugas kelompok 11

from google.colab import drive

#accessing My Google Drive
drive.mount('/content/gdrive')
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np


img = cv.imread('/content/gdrive/MyDrive/PCVK_MM/Images/ktm.png')



ktm_masked = img.copy()

# Tutup bagian Nama
cv.rectangle(ktm_masked, (60, 540), (450, 590), (0, 0, 0), -1)  # hitam

# Tutup bagian NIM
cv.rectangle(ktm_masked, (60, 590), (450, 640), (255, 0, 0), -1)  # biru

# Tutup bagian Prodi
cv.rectangle(ktm_masked, (60, 640), (450, 690), (0, 255, 0), -1)  # hijau

# Tampilkan hasil
cv2_imshow(ktm_masked)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# <PIL.Image.Image image mode=RGB size=712x1126>
